9, 59.4, 62.6, 59.4, 63.1, 59.1, 62.9, 59.1, 62.9, 59.5, 62.9, 59.3, 63.1, 59.2, 62.9, 59.5, 63.1, 59.3, 63.2, 59.4, 63.2, 59.5, 63.0, 59.5, 63.2, 59.4, 63.1, 59.5, 63.3, 59.6, 63.5, 59.5, 63.3, 59.4, 63.4, 59.7, 63.4, 59.4, 63.4, 59.7, 63.3, 59.4, 63.2, 59.6, 63.5, 59.3, 63.5, 59.3, 63.4, 59.7, 63.5, 59.4, 63.7, 59.7, 63.7, 59.7, 63.8, 59.4, 63.7, 59.5, 63.7, 59.8, 63.9, 59.8, 63.6, 59.5, 63.8, 59.8, 63.8, 59.6, 63.9, 59.6, 64.1, 59.7, 63.9, 60.0, 64.0, 59.7, 64.0, 59.7, 63.8, 60.0, 64.0, 60.2, 64.1, 60.0, 64.2, 59.9, 64.3, 59.9, 64.1, 60.1, 64.3, 60.0, 64.3, 60.3, 64.3, 60.3, 64.3, 60.1, 64.5, 60.4, 64.4, 60.4, 64.4, 60.5, 64.4, 60.2, 64.4, 60.5, 64.5, 60.2, 64.5, 60.6, 64.7, 60.3, 64.7, 60.6, 64.6, 60.7, 64.5, 60.4, 64.6, 60.7, 64.6, 60.7, 64.6, 60.7, 64.7, 60.7, 64.8, 60.6, 64.8, 60.2, 64.8, 60.3, 64.8, 60.4, 64.9, 60.7, 65.0, 60.5, 65.1, 60.8, 65.2, 60.8, 65.2, 61.0, 65.1, 61.1, 65.1, 61.0, 65.1, 60.8, 65.0, 60.9, 65.3, 61.2, 65.3, 60.9, 65.2, 61.0, 65.1, 61.0, 65.4, 61.2, 65.3, 61.3, 65.1, 61.3, 65.4, 61.2, 65.5, 61.0, 65.3, 61.3, 65.3, 61.3, 65.6, 61.1, 65.5, 61.3, 65.4, 61.4, 65.5, 61.2, 65.4, 61.1, 65.6, 61.4, 65.4, 61.4, 65.5, 61.2, 65.5, 61.6, 65.8, 61.5, 65.8, 61.5, 65.7, 61.4, 65.7, 61.4, 65.8, 61.5, 65.8, 61.2, 65.7, 61.3, 65.7, 61.3, 65.8, 61.6, 65.8, 61.3, 65.9, 61.7, 65.9, 61.4, 66.1, 61.7, 65.8, 61.5, 65.9, 61.6, 66.1, 62.0, 66.0, 61.8, 65.9, 61.9, 66.1, 61.9, 66.0, 61.6, 66.2, 61.8, 66.1, 61.8, 66.1, 61.6, 66.0, 61.6, 66.1, 61.8, 66.3, 61.8, 66.3, 61.8, 66.2, 61.5, 66.2, 61.8, 66.2, 61.8, 66.3, 61.9, 66.3, 61.9, 66.3, 61.5, ])

# %%
plt.plot(data)
plt.grid(b=True, which='both', color='0.65',linestyle='-')
# The difference between train and test suggest image distortions would help
# The continued progress after 18 hours strongly suggests that actually using GPUs would help

# %%
n = data.shape[0]

# %%
plt.plot(data[np.linspace(0, n-2, (n-2)/2+1, dtype=np.int16)])
plt.title('Train Accuracy')
plt.grid(b=True, which='both', color='0.65',linestyle='-')

# %%
plt.plot(data[np.linspace(1, n-1, (n-1)/2+1, dtype=np.int16)])
plt.title('Test Accuracy')
plt.xlabel('epoch')
plt.grid(b=True, which='both', color='0.65',linestyle='-')
